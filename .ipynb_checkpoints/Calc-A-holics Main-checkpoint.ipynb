# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
y = pd.read_csv('data/training_set_labels.csv').drop('respondent_id', axis = 1)

X = pd.read_csv('data/training_set_features.csv').drop('respondent_id', axis = 1)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
model_rocauc_h1n1, h1n1_logloss = ({'Naive_Bayes_Base':0.715, 
                'Logistic_Regression_Base':0.864, 
                'Logistic_Regression_Tuned':0.852, 
                'Random_Forest_Base':0.8431,
                'Random_Forest_Tuned':0.869,
                'Gradient_Boost_Base':0.825,
                'Gradient_Boost_Tuned':0.856,
                'CatBoost w/ Optuna':0.871},
                {'Naive_Bayes_Base_Logloss':0.715, 
                'Logistic_Regression_Base_Logloss':0.864, 
                'Logistic_Regression_Tuned_Logloss':0.852, 
                'Random_Forest_Base_Logloss':0.8431,
                'Random_Forest_Tuned_Logloss':0.869,
                'Gradient_Boost_Base_Logloss':0.825,
                'Gradient_Boost_Tuned_Logloss':0.856,
                'CatBoost w/ Optuna_Logloss':0.435})

model_rocauc_seasonal, seasonal_logloss = ({'Naive_Bayes_Base':0.721,
                'Logistic_Regression_Base':0.859, 
                'Logistic_Regression_Tuned':0.859, 
                'Random_Forest_Base':0.843, 
                'Random_Forest_Tuned':0.859,
                'Gradient_Boost_Base':0.852,
                'Gradient_Boost_Tuned':0.863, 
                'CatBoost w/ Optuna':0.864},
                {'Naive_Bayes_Base_Logloss':0.715, 
                'Logistic_Regression_Base_Logloss':0.864, 
                'Logistic_Regression_Tuned_Logloss':0.852, 
                'Random_Forest_Base_Logloss':0.8431,
                'Random_Forest_Tuned_Logloss':0.869,
                'Gradient_Boost_Base_Logloss':0.825,
                'Gradient_Boost_Tuned_Logloss':0.856,
                'CatBoost w/ Optuna_Logloss':0.450})

# %%
x = list(model_rocauc_h1n1.keys())
y = list(model_rocauc_h1n1.values())
#y_1 = h1n1_logloss.values()

fig, ax1 = plt.subplots(figsize=(20,12))
sns.set_style("darkgrid")

#ax2 = ax1.twinx()
ax1 = sns.barplot(x, y, palette='magma')
#ax2.plot(x, y_1, 'k-', linewidth=4)
ax1.set_xlabel('Models', fontsize=20)

ax1.set_ylabel('ROC/AUC Scores', color='black', fontsize=20)
#ax2.set_ylabel('Logloss', color='b', fontsize=20)

ax1.set_title('H1N1 Model Improvements', fontsize=20)

for i, v in enumerate(y):
    plt.text(i - 0.1, v + 0.02, str(v))
plt.show();
# Out:
# C:\Users\grego\anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
y1
# Out:
# [0.721, 0.859, 0.859, 0.843, 0.859, 0.852, 0.863, 0.864]

# %%
x1 = list(model_rocauc_seasonal.keys())
y1 = list(model_rocauc_seasonal.values())
#y1_1 = seasonal_logloss.values()

fig, ax1 = plt.subplots(figsize=(20,12))
sns.set_style("darkgrid")

#ax2 = ax1.twinx()
ax = sns.barplot(x1, y1, palette='magma')
#ax2.plot(x, y1, 'k-', linewidth=4)
ax.set_xlabel('Models', fontsize=20)

ax.set_ylabel('ROC/AUC Scores', color='black', fontsize=20)
#ax2.set_ylabel('Logloss', color='b', fontsize=20)

ax.set_title('Seasonal Model Improvements', fontsize=20)

for i, v in enumerate(y1):
    plt.text(i - 0.1, v + 0.02, str(v))
plt.show();
# Out:
# C:\Users\grego\anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
x
# Out:
# dict_keys(['Naive_Bayes_Base', 'Logistic_Regression_Base', 'Logistic_Regression_Tuned', 'Random_Forest_Base', 'Random_Forest_Tuned', 'Gradient_Boost_Base', 'Gradient_Boost_Tuned', 'CatBoost w/ Optuna'])

# %% [markdown]
# # import pickle
# with open("models/Logistic_regresion/h1n1/model_2.pickl", "rb") as f:
#     x = pickle.load(f)

# %%
x
# Out:
# LogisticRegression(C=10, fit_intercept=False, max_iter=300)

# %%
x.predict(X_test)
